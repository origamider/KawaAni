# %%
import pandas as pd

# %%
df = pd.read_csv('../data/anime_cleaned.csv')

# %%
df.value_counts()
# Out:
# anime_id  title                                                                         title_english                                                                title_japanese             title_synonyms                                                                                     image_url                                                   type  source        episodes  status           airing  aired_string                  aired                                       duration         rating                          score  scored_by  rank    popularity  members  favorites  background                                                                                                                                                                                                                                                                                                                                                                                                                 
# ...

# %%
df['score'] > 9.00
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6663     True
# 6664    False
# 6665    False
# 6666    False
# 6667    False
# Name: score, Length: 6668, dtype: bool

# %%
df[df['score'] > 9.00]
# Out:
#       anime_id                                              title  \
# 223      11061                             Hunter x Hunter (2011)
# 529      32281                                     Kimi no Na wa.
# 639      28977                                           Gintama°
# 668      35180                         3-gatsu no Lion 2nd Season
# 1261      5114                   Fullmetal Alchemist: Brotherhood
# 1366      4181                               Clannad: After Story
# 1475      9253                                        Steins;Gate
# 2774     15417                           Gintama&#039;: Enchousen
# 2953     30484                                      Steins;Gate 0
# 3147       918                                            Gintama
# 3156     28851                                     Koe no Katachi
# 3181     35247                         Owarimonogatari 2nd Season
# 4284      9969                                      Gintama&#039;
# ...
